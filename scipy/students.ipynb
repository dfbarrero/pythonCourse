# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
#data = sns.load_dataset('tips')
data = pd.read_csv("UMN_students-2011.csv")

# %%
data.head()
# Out:
#    id      weight     height     sex   race
# 0   1  143.598135  80.638220  Female  White
# 1   2  109.094417  83.736650  Female  Black
# 2   3  148.560463  63.267417  Female   Hisp
# 3   4  104.881119  54.662571  Female   Hisp
# 4   5  141.527108  81.147186  Female  Black

# %%
sns.distplot(data['weight'])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="weight", y="height", data=data)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.FacetGrid(data, col="sex")
g.map(plt.hist, "weight");

# %%
g = sns.FacetGrid(data, col="sex")
g.map(plt.hist, "height");

# %%
sns.jointplot(x='weight', y='height', kind="hex", color="k", data=data);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x="weight", y="height", data=data, kind="kde");

# %%
g = sns.FacetGrid(data, row="race")
g.map(plt.hist, "height");

# %%
g = sns.FacetGrid(data, row="sex")
g.map(plt.hist, "height");

# %%
sns.set()

# %%
sns.distplot(data['weight']);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot("total_bill", "tip", tips , kind="hex")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b9f236ac76f1> in <module>()
# ----> 1 sns.jointplot("total_bill", "tip", tips , kind="hex")
#
# NameError: name 'tips' is not defined
